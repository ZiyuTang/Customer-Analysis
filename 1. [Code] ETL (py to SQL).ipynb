# %%
import pandas as pd

# %%
final_df = pd.read_csv("~/Downloads/npidata_pfile_20050523-20191013.csv",usecols = [1,31,41,47,49,307])

# %%
final_df
# Out:
#          Entity Type Code  \
# 0                     1.0
# 1                     1.0
# 2                     2.0
# 3                     1.0
# 4                     1.0
# 5                     2.0
# 6                     1.0
# 7                     1.0
# 8                     1.0
# 9                     1.0
# 10                    1.0
# 11                    1.0
# 12                    1.0
# 13                    1.0
# 14                    1.0
# 15                    2.0
# 16                    1.0
# 17                    1.0
# 18                    1.0
# 19                    1.0
# 20                    1.0
# 21                    2.0
# 22                    1.0
# 23                    1.0
# 24                    1.0
# 25                    1.0
# 26                    1.0
# 27                    2.0
# 28                    1.0
# 29                    1.0
# ...                   ...
# 6167621               1.0
# 6167622               1.0
# 6167623               1.0
# ...

# %%
type(final_df)
# Out:
# pandas.core.frame.DataFrame

# %%
export_csv = final_df.to_csv ("~/Downloads/analyze_data.csv", index = None, header=True) #Don't forget to add '.csv' at the end of the path
